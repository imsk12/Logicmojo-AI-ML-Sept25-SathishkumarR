# %% [markdown]
# <a href="https://colab.research.google.com/github/imsk12/Logicmojo-AI-ML-Sept25-SathishkumarR/blob/main/python_refresher_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class work 14/09/2025

# %%
# My try
# x = int(input("enter a number: "))
# for num in x:
#     if (num == 5):
#       break
#     elif(num %4 == 0):
#       pass
#     print(num * num)

#From Class
while True:
  num = int(input("enter a number: "))
  if (num == 5):
    break
  elif(num %4 == 0):
    continue
  print(num ** 2)
# Out:
# enter a number: 1
# 1
# enter a number: 5

# %%
for i in range(3):
    for j in range(5):
        print("*",end="")
    print()
# Out:
# *****
# *****
# *****

# %%
for i in range(6):
  for j in range(i):
    print("*", end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
rows = 3
for i in range(rows):
  for j in range(rows-i-1):
      print(" ",end="")
  for z in range(2*i+1):
      print("*",end="")
  print()
# Out:
#   *
#  ***
# *****
